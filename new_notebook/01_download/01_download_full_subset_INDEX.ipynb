# %% [markdown]
# # 01 - Full Subset Download Index
#
# File này chỉ là index cho các notebook download full subset riêng lẻ.
#
# Chạy theo thứ tự:
#
# 1. P1 `p1_gr1_safe` trước, vì dùng trực tiếp được với Notebook 02/03 hiện tại.
# 2. P2 `p2_gr1_experimental` nếu còn disk/GPU time.
# 3. P3 `p3_cross_embodiment` để làm bằng chứng data diversity, nhưng chưa đưa thẳng vào Notebook 02/03 hiện tại.

# %%
import pandas as pd
rows = [{'order': 1, 'notebook': '01_download/01_download_full_01_gr1_arms_waist_PlaceMilkToMicrowave.ipynb', 'subset': 'gr1_arms_waist.PlaceMilkToMicrowave', 'priority_group': 'p1_gr1_safe', 'pipeline_safe_for_notebook02': True, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 2, 'notebook': '01_download/01_download_full_02_gr1_arms_waist_PotatoToMicrowave.ipynb', 'subset': 'gr1_arms_waist.PotatoToMicrowave', 'priority_group': 'p1_gr1_safe', 'pipeline_safe_for_notebook02': True, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 3, 'notebook': '01_download/01_download_full_03_gr1_arms_waist_PlateToBowl.ipynb', 'subset': 'gr1_arms_waist.PlateToBowl', 'priority_group': 'p1_gr1_safe', 'pipeline_safe_for_notebook02': True, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 4, 'notebook': '01_download/01_download_full_04_gr1_arms_waist_PlateToPlate.ipynb', 'subset': 'gr1_arms_waist.PlateToPlate', 'priority_group': 'p1_gr1_safe', 'pipeline_safe_for_notebook02': True, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 5, 'notebook': '01_download/01_download_full_05_gr1_arms_waist_TrayToPlate.ipynb', 'subset': 'gr1_arms_waist.TrayToPlate', 'priority_group': 'p1_gr1_safe', 'pipeline_safe_for_notebook02': True, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 6, 'notebook': '01_download/01_download_full_06_gr1_arms_waist_WineToCabinet.ipynb', 'subset': 'gr1_arms_waist.WineToCabinet', 'priority_group': 'p1_gr1_safe', 'pipeline_safe_for_notebook02': True, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 7, 'notebook': '01_download/01_download_full_07_gr1_arms_waist_CuttingboardToBasket.ipynb', 'subset': 'gr1_arms_waist.CuttingboardToBasket', 'priority_group': 'p1_gr1_safe', 'pipeline_safe_for_notebook02': True, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 8, 'notebook': '01_download/01_download_full_08_gr1_arms_waist_CuttingboardToPan.ipynb', 'subset': 'gr1_arms_waist.CuttingboardToPan', 'priority_group': 'p1_gr1_safe', 'pipeline_safe_for_notebook02': True, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 9, 'notebook': '01_download/01_download_full_09_gr1_arms_waist_PlaceBottleToCabinet.ipynb', 'subset': 'gr1_arms_waist.PlaceBottleToCabinet', 'priority_group': 'p1_gr1_safe', 'pipeline_safe_for_notebook02': True, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 10, 'notebook': '01_download/01_download_full_10_gr1_arms_waist_PlacematToBowl.ipynb', 'subset': 'gr1_arms_waist.PlacematToBowl', 'priority_group': 'p1_gr1_safe', 'pipeline_safe_for_notebook02': True, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 11, 'notebook': '01_download/01_download_full_11_gr1_arms_waist_TrayToPot.ipynb', 'subset': 'gr1_arms_waist.TrayToPot', 'priority_group': 'p1_gr1_safe', 'pipeline_safe_for_notebook02': True, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 12, 'notebook': '01_download/01_download_full_12_gr1_arms_waist_TrayToTieredShelf.ipynb', 'subset': 'gr1_arms_waist.TrayToTieredShelf', 'priority_group': 'p1_gr1_safe', 'pipeline_safe_for_notebook02': True, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 13, 'notebook': '01_download/01_download_full_13_gr1_full_upper_body_Coffee.ipynb', 'subset': 'gr1_full_upper_body.Coffee', 'priority_group': 'p2_gr1_experimental', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 14, 'notebook': '01_download/01_download_full_14_gr1_full_upper_body_Pouring.ipynb', 'subset': 'gr1_full_upper_body.Pouring', 'priority_group': 'p2_gr1_experimental', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 15, 'notebook': '01_download/01_download_full_15_gr1_unified_PnPCanToDrawerClose_GR1ArmsAndWaistFourierHands_1000.ipynb', 'subset': 'gr1_unified.PnPCanToDrawerClose_GR1ArmsAndWaistFourierHands_1000', 'priority_group': 'p2_gr1_experimental', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 16, 'notebook': '01_download/01_download_full_16_gr1_unified_PnPCupToDrawerClose_GR1ArmsAndWaistFourierHands_1000.ipynb', 'subset': 'gr1_unified.PnPCupToDrawerClose_GR1ArmsAndWaistFourierHands_1000', 'priority_group': 'p2_gr1_experimental', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 17, 'notebook': '01_download/01_download_full_17_gr1_unified_PnPBottleToCabinetClose_GR1ArmsAndWaistFourierHands_1000.ipynb', 'subset': 'gr1_unified.PnPBottleToCabinetClose_GR1ArmsAndWaistFourierHands_1000', 'priority_group': 'p2_gr1_experimental', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 18, 'notebook': '01_download/01_download_full_18_bimanual_panda_gripper_Threading.ipynb', 'subset': 'bimanual_panda_gripper.Threading', 'priority_group': 'p3_cross_embodiment', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 19, 'notebook': '01_download/01_download_full_19_bimanual_panda_gripper_Transport.ipynb', 'subset': 'bimanual_panda_gripper.Transport', 'priority_group': 'p3_cross_embodiment', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 20, 'notebook': '01_download/01_download_full_20_single_panda_gripper_PnPCounterToCab.ipynb', 'subset': 'single_panda_gripper.PnPCounterToCab', 'priority_group': 'p3_cross_embodiment', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 21, 'notebook': '01_download/01_download_full_21_single_panda_gripper_OpenDrawer.ipynb', 'subset': 'single_panda_gripper.OpenDrawer', 'priority_group': 'p3_cross_embodiment', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 22, 'notebook': '01_download/01_download_full_22_single_panda_gripper_CoffeeServeMug.ipynb', 'subset': 'single_panda_gripper.CoffeeServeMug', 'priority_group': 'p3_cross_embodiment', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 23, 'notebook': '01_download/01_download_full_23_sim_behavior_r1_pro_task_0001_picking_up_trash.ipynb', 'subset': 'sim_behavior_r1_pro.task-0001_picking_up_trash', 'priority_group': 'p3_cross_embodiment', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 24, 'notebook': '01_download/01_download_full_24_sim_behavior_r1_pro_task_0020_sorting_vegetables.ipynb', 'subset': 'sim_behavior_r1_pro.task-0020_sorting_vegetables', 'priority_group': 'p3_cross_embodiment', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}, {'order': 25, 'notebook': '01_download/01_download_full_25_unitree_g1_LMPnPAppleToPlateDC.ipynb', 'subset': 'unitree_g1.LMPnPAppleToPlateDC', 'priority_group': 'p3_cross_embodiment', 'pipeline_safe_for_notebook02': False, 'default_download_mode': 'data_meta_ego_chunks'}]
df = pd.DataFrame(rows)
display(df)
df.to_csv('/kaggle/working/download_full_subset_index.csv', index=False)
